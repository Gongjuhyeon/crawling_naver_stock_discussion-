# %%
# !pip install selenium
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 995 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 384 kB 77.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 48.0 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [913 kB]
# ...

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://Gongjuhyeon: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@github.com/Gongjuhyeon/crawling_naver_stock_discussion-.git
# Out:
# Cloning into 'crawling_naver_stock_discussion-'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd /content/drive/MyDrive/Hcc lab project/crawling_naver_stock_discussion-
# Out:
# /content/drive/MyDrive/Hcc lab project/crawling_naver_stock_discussion-

# %%
# !git config --global user.email 'kjh000121@gmail.com'
# !git config --global user.name 'Gongjuhyeon'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	crawling_naver_stock_discussion-/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add 주식 crawling.ipynb

# !git commit -m "Connect Google Colab and Drive"
# Out:
# fatal: pathspec '주식' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	"11401\341\204\200\341\205\242 \341\204\202\341\205\242\341\204\213\341\205\255\341\206\274 \341\204\216\341\205\256\341\204\200\341\205\241 - \341\204\211\341\205\241\341\206\267\341\204\211\341\205\245\341\206\274\341\204\214\341\205\245\341\206\253\341\204\214\341\205\241 \341\204\217\341\205\263\341\204\205\341\205\251\341\206\257\341\204\205\341\205\265\341\206\274.xlsx"
# 	crawling_naver_stock_discussion-/
# 	samsungdf.xlsx
# 	samsungdf1.xlsx
# 	"samsungdf1.xlsx\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253dd"
# 	"\341\204\214\341\205\256\341\204\211\341\205\265\341\206\250 crawling.ipynb"
#
# nothing added to commit but untracked files present

# %%
# !git push -u origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 8.67 KiB | 683.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/Gongjuhyeon/crawling_naver_stock_discussion-.git
#    4729732..f73e4fc  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless') # browser를 띄우지 않고 실행하기
options.add_argument('--no-sandbox') # sandbox 기능을 비활성화 하기
options.add_argument('--disable-dev-shm-usage') # dev/shm/ 폴더를 사용하지 않기

# %%
from time import sleep
import pandas as pd
import re

# %% [markdown]
# 주식종목 찾기

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import urllib.request
from urllib.request import urlopen


headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/100.0.48496.75" }
#search=urllib.parse.quote_plus(search)
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# 주식 종목명 클릭후 종목토론실 클릭하기

# %%
df1 = pd.DataFrame([])

# %% [markdown]
# # 저장

# %%
def page(search,num,df,final_nid):
    driver = webdriver.Chrome('chromedriver',options=options)
    url=f"https://finance.naver.com/item/board.naver?code="+str(search)+"&page="+str(num)

    r = driver.get(url) #해당 url로 이동   
    
    sleep(3) 
    html1 = driver.current_url #현재 페이지 소스
    print(html1)
                               
    result = requests.get(html1, headers = headers)

   
    bs_obj = BeautifulSoup(result.content, "html.parser")
    table = bs_obj.find('table', {'class' : 'type2'})
    tt = table.select('tbody > tr')
    print("final_nid =" , final_nid)
    for i in range(2, len(tt)):
        if len(tt[i].select('td > span')) > 0:
            date = tt[i].select('td > span')[0].text
            title = tt[i].select('td.title > a')[0]['title']
            writer = tt[i].select('td.p11')[0].text.replace('\t', '').replace('\n', '')
            views = tt[i].select('td > span')[1].text
            links=tt[i].select('td.title > a') [0]['href']
            code=tt[i].select('td.title > a')[0]['href']
            code=re.split(r'[?&]',code)
            code=re.split(r'code=',code[1])
            
            nid=tt[i].select('td.title > a')[0]['href']
            nid=re.split(r'[?&]',nid)
            nid=re.split(r'nid=',nid[2])
            
            c=tt[i].find('b')
            if(c==None):
                review_count=0
                
            else:
                review_count=tt[i].select('td.title > a > span > b ')[0].text.replace('/(<[^>]+)>)/',"")
        
            sleep(2)
            
            table = pd.DataFrame({'날짜' : [date], 
                    '제목' : [title],
                    '글쓴이' : [writer],
                    '조회' : [views],
                    '댓글 수': [review_count],
                    'code': [code[1]],
                    'nid':[nid[1]],
                    'link':links
                    })
            df = df.append(table)

            if(nid[1]==final_nid):
                df =pd.DataFrame([])
            if((len(tt)-2)==i):
                final_nid=nid[1]
        
    driver.quit()
    return df,final_nid

# %%
df = pd.DataFrame([])

# %%
final_nid=0
for i in range(4793,83274,1):
    df2,final_nid=page('005930',i,df,final_nid)
    df1=df1.append(df2)
# Out:
# https://finance.naver.com/item/board.naver?code=005930&page=4793
# final_nid = 0
# https://finance.naver.com/item/board.naver?code=005930&page=4794
# final_nid = 227982813
# https://finance.naver.com/item/board.naver?code=005930&page=4795
# final_nid = 227982530
# https://finance.naver.com/item/board.naver?code=005930&page=4796
# final_nid = 227982088
# https://finance.naver.com/item/board.naver?code=005930&page=4797
# final_nid = 227981732
# https://finance.naver.com/item/board.naver?code=005930&page=4798
# final_nid = 227981314
# https://finance.naver.com/item/board.naver?code=005930&page=4799
# final_nid = 227980932
# https://finance.naver.com/item/board.naver?code=005930&page=4800
# final_nid = 227978548
# https://finance.naver.com/item/board.naver?code=005930&page=4801
# final_nid = 227977706
# https://finance.naver.com/item/board.naver?code=005930&page=4802
# final_nid = 227976629
# https://finance.naver.com/item/board.naver?code=005930&page=4803
# final_nid = 227976365
# ...

# %%
df1
# Out:
#                   날짜                                   제목       글쓴이   조회 댓글 수  \
# 0   2022.08.10 09:13                           배당 많이 주겠지?  stou****  237    0
# 0   2022.08.10 09:13                        와 프로글매 폭풍 매도네  khs9****  220    0
# 0   2022.08.10 09:13                               오만의저주   ophe****  212    0
# 0   2022.08.10 09:13                                   삼전  2tjd****  207    0
# 0   2022.08.10 09:12                       호구전자 강력매수신호 발생  ssun****  241    1
# ..               ...                                  ...       ...  ...  ...
# 0   2022.08.05 17:29                    윤무당은 국민이 하지말라는것만   ynew****  224    1
# 0   2022.08.05 17:28                           이유를 알았네     knso****  234    0
# 0   2022.08.05 17:28                                이준석은   jaew****  225    0
# 0   2022.08.05 17:30  [삭제된 게시물의 답글]정신병동에 아이유 서방이란 놈들이 수두룩  qufd****  214    0
# 0   2022.08.05 17:28   [삭제된 게시물의 답글]저기 민주당으로 가거라 준식아 ㅋㅋㅋㅋ  scie****  218    0
#
# ...

# %% [markdown]
# # 두번째 시트에 저장

# %%
import openpyxl
workbook = openpyxl.load_workbook('/content/drive/MyDrive/Hcc lab project/samsungdf1.xlsx')
writer = pd.ExcelWriter('/content/drive/MyDrive/Hcc lab project/samsungdf1.xlsx', engine='openpyxl')
writer.book = workbook
writer.sheets = dict((ws.title, ws) for ws in workbook.worksheets)
df1.to_excel(writer, 'sheet13',index=False, header=True)
writer.save()
writer.close()

# %% [markdown]
# **새 시트를 추가하는 코드**

# %%
import os
import pandas as pd
from openpyxl import load_workbook

# %%
with pd.ExcelWriter('/content/drive/MyDrive/Hcc lab project/samsungdf111.xlsx', mode='w', engine='openpyxl') as writer:
    df1.to_excel(writer, index=False, header=True)

# %% [markdown]
# # 맨뒤 페이지 - 실행할 때 맨뒤 페이지

# %% [markdown]
# ex) 81368(2022-09-13 오후 3:46)

# %%
def page_search(search):
    driver = webdriver.Chrome('chromedriver',options=options)
    url=f"https://finance.naver.com/item/board.naver?code="+str(search)

    r = driver.get(url) #해당 url로 이동   

    sleep(3) 
    html1 = driver.current_url #현재 페이지 소스
    
    result = requests.get(html1, headers = headers)

    bs_obj = BeautifulSoup(result.content, "html.parser")
    content_btn = driver.find_element(by=By.XPATH,value='//*[@id="content"]/div[2]/table[2]/tbody/tr/td[2]/table/tbody/tr/td[12]/a'); 
    #마지막 페이지
    content_btn.click()

    html2 = driver.current_url #현재 페이지 소스
    driver.quit()
    return html2[-5:]

# %%
final_page=page_search('005930')

# %%
print(final_page)
# Out:
# 83377

# %%
sub_pagenum=int(final_page)-83296

# %%
print(sub_pagenum)
# Out:
# 81

# %% [markdown]
# # nid 같은지 확인

# %%
def find_start_page(search,num,d):
    driver = webdriver.Chrome('chromedriver',options=options)
    url=f"https://finance.naver.com/item/board.naver?code="+str(search)+"&page="+str(num)

    r = driver.get(url) #해당 url로 이동   
    
    sleep(3) 
    html1 = driver.current_url #현재 페이지 소스
    print(html1)
                               
    result = requests.get(html1, headers = headers)

   
    bs_obj = BeautifulSoup(result.content, "html.parser")
    table = bs_obj.find('table', {'class' : 'type2'})
    tt = table.select('tbody > tr')

    for i in range(2, len(tt)):
        if len(tt[i].select('td > span')) > 0:
            nid=tt[i].select('td.title > a')[0]['href']
            nid=re.split(r'[?&]',nid)
            nid=re.split(r'nid=',nid[2])
            
            if(nid==d):
                print(num)
                break
            sleep(2)
            
            
    driver.quit()
    return num,i

# %%
for j in range(2867+sub_pagenum+20,int(final_page),1):
    find_start_page('005930',j,227957473)#세번째 param 마지막 nid
# Out:
# https://finance.naver.com/item/board.naver?code=005930&page=3003
# https://finance.naver.com/item/board.naver?code=005930&page=3004
# https://finance.naver.com/item/board.naver?code=005930&page=3005
# https://finance.naver.com/item/board.naver?code=005930&page=3006
# https://finance.naver.com/item/board.naver?code=005930&page=3007
# https://finance.naver.com/item/board.naver?code=005930&page=3008
# https://finance.naver.com/item/board.naver?code=005930&page=3009
# https://finance.naver.com/item/board.naver?code=005930&page=3010
# https://finance.naver.com/item/board.naver?code=005930&page=3011
# https://finance.naver.com/item/board.naver?code=005930&page=3012
# https://finance.naver.com/item/board.naver?code=005930&page=3013
# https://finance.naver.com/item/board.naver?code=005930&page=3014
# https://finance.naver.com/item/board.naver?code=005930&page=3015
# https://finance.naver.com/item/board.naver?code=005930&page=3016
# ...

# %%
    options.add_argument('--headless') # browser를 띄우지 않고 실행하기
options.add_argument('--no-sandbox') # sandbox 기능을 비활성화 하기
options.add_argument('--disable-dev-shm-usage') # dev/shm/ 폴더를 사용하지 않기

# %%
result = requests.get(html1, headers = headers)
bs_obj = BeautifulSoup(result.content, "html.parser")
table = bs_obj.find('table', {'class' : 'type2'})
tt = table.select('tbody > tr')

tt = table.select('tbody > tr')

for i in range(2, len(tt)):
    if len(tt[i].select('td > span')) > 0:
        date = tt[i].select('td > span')[0].text
        title = tt[i].select('td.title > a')[0]['title']
        writer = tt[i].select('td.p11')[0].text.replace('\t', '').replace('\n', '')
        views = tt[i].select('td > span')[1].text

        # print(date, title, writer, views, pos, neg)

        table = pd.DataFrame({'날짜' : [date], 
                '제목' : [title],
                '글쓴이' : [writer],
                '조회' : [views]
                })
        total_dt = total_dt.append(table)

# %%
driver.current_url

# %% [markdown]
# # content 뽑아오기

# %%
        content_btn = driver.find_element(by=By.XPATH,value='//*[@id="content"]/div[2]/table[1]/tbody/tr[%d]/td[2]/a'%j); 
        # 로그인 하기 버튼 위치
        content_btn.click()
        html2 = driver.current_url #현재 페이지 소스
        print(html2)
        result1 = requests.get(html2, headers = headers)
        bs = BeautifulSoup(result1.content, "html.parser")
        content=bs.find('div',{'class':'scr01'}).find_all(text=True)
        #content=bs1.select('#body')[0]
        #content=content.find_all('br')
        content = " ".join(content)
        compi=re.compile('\(+[가-힣0-9a-zA-Z\-_, ]+\)')
        content=re.sub(compi,"",str(content))
